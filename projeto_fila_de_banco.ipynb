# %% [markdown]
# # Fila de caixa

# %% [markdown]
# #### Este estudo tem como objetivo a construção de um modelo analítico que fará a previsão do percentual de atendimentos com espera acima de 15 minutos, para auxiliar na criação de estratégias para a redução desse tempo.

# %% [markdown]
# #### Nos dias atuais, o dinamismo é um dos fatores-chave na relação entre pessoas e organizações. Qualquer tipo de atraso operacional é visto como uma característica negativa e acarreta o descontentamento por parte dos clientes.

# %% [markdown]
# #### A espera em uma fila de banco pode ser crítica, uma vez que o tempo percebido pelo consumidor pode ser maior que o analisado pela instituição. E a demora no atendimento é, muitas vezes, o motivo da insatisfação da percepção geral do atendimento.

# %% [markdown]
# #### Neste contexto, temos a seguinte situação: em Datacity temos 25 agências bancárias que possuem serviço de caixa. Pensando no bem-estar dos nossos clientes, seria importante saber o percentual de atendimento que foi iniciado com tempo de espera acima de 15 minutos. O estudo visa trazer informações para cada hora, sabendo que o horário de funcionamento é das 10h às 14h. Essas informações irão colaborar com a construção da estratégia de atuação, que tem como objetivo reduzir o tempo de atendimento.

# %% [markdown]
# ### Para realizar a análise, foi utilizada uma base pública de dados, em formato csv, contendo as seguintes variáveis:
# * ID - Código identificador único para cada protocolo gerado;
# * ID_UOR - Código da agência, indicado por uma sequência de 0 a 24;
# * TS_INC_EPR - Timestamp do início da espera, ou seja, a data e hora de emissão do protocolo;
# * TS_INC_CHMD - Timestamp da chamada do protocolo

# %% [markdown]
# ### Os protocolos foram agrupados por faixa de horário, tendo como referência a variável TS_INC_EPR
# * DT - Recebe a data do atendimento;
# * HH_INC - Recebe o horário de TS_INC_EPR;
# * HH_FIM - Recebe o horário de TS_INC_CHMD;
# * Exemplo de cálculo PC_AC_PZ (percentual acima do prazo):
# ** Dentre os protocolos emitidos entre 10h e 10:59:59, em determinado dia para determinada UOR, 8 (oito) foram atendidos em até 15 minutos  e 2 (dois) foram atendidos com espera superior a 15 minutos. A proporção atendida acima do prazo é 20%.

# %%
# Importando as bibliotecas.
import pandas as pd
import datetime
import numpy as np

# %%
# Lendo o dataframe.
dados = pd.read_csv('Dataset_publico.csv', sep=';')
dados.head()
# Out:
#    ID  ID_UOR           TS_INC_EPR          TS_INC_CHMD
# 0   0       0  2020-09-01 10:01:24  2020-09-01 10:02:13
# 1   1       0  2020-09-01 10:04:21  2020-09-01 10:22:01
# 2   2       0  2020-09-01 10:16:14  2020-09-01 10:25:06
# 3   3       0  2020-09-01 10:28:38  2020-09-01 10:28:40
# 4   4       0  2020-09-01 10:37:38  2020-09-01 10:37:41

# %%
dados["DT"] = dados["TS_INC_EPR"].str[:10]
dados["DT"] = pd.to_datetime(dados["DT"])

# %%
dados.head()
# Out:
#    ID  ID_UOR           TS_INC_EPR          TS_INC_CHMD         DT
# 0   0       0  2020-09-01 10:01:24  2020-09-01 10:02:13 2020-09-01
# 1   1       0  2020-09-01 10:04:21  2020-09-01 10:22:01 2020-09-01
# 2   2       0  2020-09-01 10:16:14  2020-09-01 10:25:06 2020-09-01
# 3   3       0  2020-09-01 10:28:38  2020-09-01 10:28:40 2020-09-01
# 4   4       0  2020-09-01 10:37:38  2020-09-01 10:37:41 2020-09-01

# %%
# Informações sobre o dataframe.

# %%
dados.shape
# Out:
# (335612, 5)

# %%
dados.describe()
# Out:
#                   ID         ID_UOR
# count  335612.000000  335612.000000
# mean   187666.925459      10.849687
# std    109062.064477       7.299419
# min         0.000000       0.000000
# 25%     93401.750000       5.000000
# 50%    186928.500000       9.000000
# 75%    282781.250000      18.000000
# max    376681.000000      24.000000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335612 entries, 0 to 335611
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           335612 non-null  int64
#  1   ID_UOR       335612 non-null  int64
#  2   TS_INC_EPR   335612 non-null  object
#  3   TS_INC_CHMD  335428 non-null  object
#  4   DT           335612 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 12.8+ MB

# %%
# Eliminando valores NaN.
dados = dados.dropna(axis=0, how='any')

# %%
# Conferindo alterações
dados.shape
# Out:
# (335428, 5)

# %%
# Convertendo as colunas "TS_INC_EPR" e "TS_INC_CHMD" para tipo datetime.

# %%
dados["TS_INC_EPR"] = pd.to_datetime(dados.TS_INC_EPR)

# %%
dados["TS_INC_CHMD"] = pd.to_datetime(dados.TS_INC_CHMD)

# %%
#Criando coluna "TS_TTL_EPR" que vai receber a diferença entre os valores das colunas "TS_INC_CHMD" 
# e "TS_INC_EPR", respectivamente.
dados["TS_TTL_EPR"] = dados["TS_INC_CHMD"] - dados["TS_INC_EPR"]

# %%
# Visualisando a nova configuração.
dados.head()
# Out:
#    ID  ID_UOR          TS_INC_EPR         TS_INC_CHMD         DT  \
# 0   0       0 2020-09-01 10:01:24 2020-09-01 10:02:13 2020-09-01
# 1   1       0 2020-09-01 10:04:21 2020-09-01 10:22:01 2020-09-01
# 2   2       0 2020-09-01 10:16:14 2020-09-01 10:25:06 2020-09-01
# 3   3       0 2020-09-01 10:28:38 2020-09-01 10:28:40 2020-09-01
# 4   4       0 2020-09-01 10:37:38 2020-09-01 10:37:41 2020-09-01
#
#        TS_TTL_EPR
# 0 0 days 00:00:49
# 1 0 days 00:17:40
# 2 0 days 00:08:52
# 3 0 days 00:00:02
# 4 0 days 00:00:03

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335428 entries, 0 to 335611
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           335428 non-null  int64
#  1   ID_UOR       335428 non-null  int64
#  2   TS_INC_EPR   335428 non-null  datetime64[ns]
#  3   TS_INC_CHMD  335428 non-null  datetime64[ns]
#  4   DT           335428 non-null  datetime64[ns]
#  5   TS_TTL_EPR   335428 non-null  timedelta64[ns]
# dtypes: datetime64[ns](3), int64(2), timedelta64[ns](1)
# memory usage: 17.9 MB

# %%
#Criando as variáveis "Acima do prazo" e "Dentro do prazo"

# %%
def tempo(element): 
    if element.total_seconds() > (15 * 60):
        return 'Acima do prazo'
    else:
        return 'Dentro do prazo'

# %%
# Criando coluna "ESP" para receber os valores "Dentro do prazo" e "Acima do prazo"
dados['ESP'] = dados.TS_TTL_EPR.map(tempo)

# %%
# Conferindo inclusão da coluna "ESP" no dataframe dados
dados.head()
# Out:
#    ID  ID_UOR          TS_INC_EPR         TS_INC_CHMD         DT  \
# 0   0       0 2020-09-01 10:01:24 2020-09-01 10:02:13 2020-09-01
# 1   1       0 2020-09-01 10:04:21 2020-09-01 10:22:01 2020-09-01
# 2   2       0 2020-09-01 10:16:14 2020-09-01 10:25:06 2020-09-01
# 3   3       0 2020-09-01 10:28:38 2020-09-01 10:28:40 2020-09-01
# 4   4       0 2020-09-01 10:37:38 2020-09-01 10:37:41 2020-09-01
#
#        TS_TTL_EPR              ESP
# 0 0 days 00:00:49  Dentro do prazo
# 1 0 days 00:17:40   Acima do prazo
# 2 0 days 00:08:52  Dentro do prazo
# 3 0 days 00:00:02  Dentro do prazo
# 4 0 days 00:00:03  Dentro do prazo

# %%
# Incluindo as colunas com os intervalos iniciais e finais dos horários

# %%
dados['HH_INC'] = dados['TS_INC_EPR'].apply(lambda x: str(x)[11:13]+':00:00')
dados.head()
# Out:
#    ID  ID_UOR          TS_INC_EPR         TS_INC_CHMD         DT  \
# 0   0       0 2020-09-01 10:01:24 2020-09-01 10:02:13 2020-09-01
# 1   1       0 2020-09-01 10:04:21 2020-09-01 10:22:01 2020-09-01
# 2   2       0 2020-09-01 10:16:14 2020-09-01 10:25:06 2020-09-01
# 3   3       0 2020-09-01 10:28:38 2020-09-01 10:28:40 2020-09-01
# 4   4       0 2020-09-01 10:37:38 2020-09-01 10:37:41 2020-09-01
#
#        TS_TTL_EPR              ESP    HH_INC
# 0 0 days 00:00:49  Dentro do prazo  10:00:00
# 1 0 days 00:17:40   Acima do prazo  10:00:00
# 2 0 days 00:08:52  Dentro do prazo  10:00:00
# 3 0 days 00:00:02  Dentro do prazo  10:00:00
# 4 0 days 00:00:03  Dentro do prazo  10:00:00

# %%
dados['HH_FIM'] = dados['TS_INC_EPR'].apply(lambda x: str(x)[11:13]+':59:59')
dados.head(50)
# Out:
#     ID  ID_UOR          TS_INC_EPR         TS_INC_CHMD         DT  \
# 0    0       0 2020-09-01 10:01:24 2020-09-01 10:02:13 2020-09-01
# 1    1       0 2020-09-01 10:04:21 2020-09-01 10:22:01 2020-09-01
# 2    2       0 2020-09-01 10:16:14 2020-09-01 10:25:06 2020-09-01
# 3    3       0 2020-09-01 10:28:38 2020-09-01 10:28:40 2020-09-01
# 4    4       0 2020-09-01 10:37:38 2020-09-01 10:37:41 2020-09-01
# 5    5       0 2020-09-01 10:39:35 2020-09-01 10:39:38 2020-09-01
# 6    6       0 2020-09-01 10:41:34 2020-09-01 10:41:36 2020-09-01
# 7    7       0 2020-09-01 10:44:22 2020-09-01 10:44:24 2020-09-01
# 8    8       0 2020-09-01 10:48:41 2020-09-01 10:48:45 2020-09-01
# 9    9       0 2020-09-01 10:49:57 2020-09-01 10:50:00 2020-09-01
# 10  10       0 2020-09-01 10:56:24 2020-09-01 11:11:05 2020-09-01
# 11  11       0 2020-09-01 10:59:26 2020-09-01 11:11:45 2020-09-01
# 12  12       0 2020-09-02 10:07:51 2020-09-02 10:07:59 2020-09-02
# 13  13       0 2020-09-02 10:08:22 2020-09-02 10:08:25 2020-09-02
# 14  14       0 2020-09-02 10:09:33 2020-09-02 10:09:37 2020-09-02
# 15  15       0 2020-09-02 10:13:52 2020-09-02 10:13:54 2020-09-02
# 16  16       0 2020-09-02 10:14:12 2020-09-02 10:14:13 2020-09-02
# 17  17       0 2020-09-02 10:16:08 2020-09-02 10:16:10 2020-09-02
# 18  18       0 2020-09-02 10:17:53 2020-09-02 10:17:57 2020-09-02
# 19  19       0 2020-09-02 10:18:13 2020-09-02 10:18:15 2020-09-02
# 20  20       0 2020-09-02 10:18:33 2020-09-02 10:18:35 2020-09-02
# 21  21       0 2020-09-02 10:21:24 2020-09-02 10:21:25 2020-09-02
# 22  22       0 2020-09-02 10:23:21 2020-09-02 10:23:23 2020-09-02
# 23  23       0 2020-09-02 10:24:37 2020-09-02 10:24:39 2020-09-02
# 24  24       0 2020-09-02 10:29:38 2020-09-02 10:29:39 2020-09-02
# 25  25       0 2020-09-02 10:31:04 2020-09-02 10:31:05 2020-09-02
# 26  26       0 2020-09-02 10:33:21 2020-09-02 10:33:23 2020-09-02
# 27  27       0 2020-09-02 10:36:37 2020-09-02 10:36:38 2020-09-02
# 28  28       0 2020-09-02 10:41:23 2020-09-02 10:41:24 2020-09-02
# 29  29       0 2020-09-02 10:45:53 2020-09-02 10:45:55 2020-09-02
# 30  30       0 2020-09-02 10:47:52 2020-09-02 10:47:54 2020-09-02
# 31  31       0 2020-09-02 10:48:08 2020-09-02 10:48:10 2020-09-02
# 32  32       0 2020-09-02 10:52:38 2020-09-02 10:52:40 2020-09-02
# 33  33       0 2020-09-02 10:53:21 2020-09-02 10:53:25 2020-09-02
# 34  34       0 2020-09-02 10:58:51 2020-09-02 10:58:52 2020-09-02
# 35  35       0 2020-09-02 11:02:54 2020-09-02 11:02:57 2020-09-02
# 36  36       0 2020-09-02 11:06:43 2020-09-02 11:21:31 2020-09-02
# 37  37       0 2020-09-02 11:21:29 2020-09-02 11:25:23 2020-09-02
# 38  38       0 2020-09-02 11:25:22 2020-09-02 11:34:18 2020-09-02
# 39  39       0 2020-09-02 11:33:25 2020-09-02 11:38:44 2020-09-02
# 40  40       0 2020-09-02 11:41:53 2020-09-02 11:41:55 2020-09-02
# 41  41       0 2020-09-02 11:42:58 2020-09-02 11:43:00 2020-09-02
# 42  42       0 2020-09-02 11:44:12 2020-09-02 11:44:13 2020-09-02
# 43  43       0 2020-09-02 11:51:06 2020-09-02 11:51:10 2020-09-02
# 44  44       0 2020-09-02 11:57:36 2020-09-02 11:57:38 2020-09-02
# 45  45       0 2020-09-02 12:00:10 2020-09-02 12:00:12 2020-09-02
# 46  46       0 2020-09-02 12:00:21 2020-09-02 12:00:29 2020-09-02
# 47  47       0 2020-09-02 12:03:43 2020-09-02 12:03:48 2020-09-02
# 48  48       0 2020-09-02 12:07:53 2020-09-02 12:07:57 2020-09-02
# 49  49       0 2020-09-02 12:12:43 2020-09-02 12:12:45 2020-09-02
#
#         TS_TTL_EPR              ESP    HH_INC    HH_FIM
# 0  0 days 00:00:49  Dentro do prazo  10:00:00  10:59:59
# 1  0 days 00:17:40   Acima do prazo  10:00:00  10:59:59
# 2  0 days 00:08:52  Dentro do prazo  10:00:00  10:59:59
# 3  0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 4  0 days 00:00:03  Dentro do prazo  10:00:00  10:59:59
# 5  0 days 00:00:03  Dentro do prazo  10:00:00  10:59:59
# 6  0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 7  0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 8  0 days 00:00:04  Dentro do prazo  10:00:00  10:59:59
# 9  0 days 00:00:03  Dentro do prazo  10:00:00  10:59:59
# 10 0 days 00:14:41  Dentro do prazo  10:00:00  10:59:59
# 11 0 days 00:12:19  Dentro do prazo  10:00:00  10:59:59
# 12 0 days 00:00:08  Dentro do prazo  10:00:00  10:59:59
# 13 0 days 00:00:03  Dentro do prazo  10:00:00  10:59:59
# 14 0 days 00:00:04  Dentro do prazo  10:00:00  10:59:59
# 15 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 16 0 days 00:00:01  Dentro do prazo  10:00:00  10:59:59
# 17 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 18 0 days 00:00:04  Dentro do prazo  10:00:00  10:59:59
# 19 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 20 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 21 0 days 00:00:01  Dentro do prazo  10:00:00  10:59:59
# 22 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 23 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 24 0 days 00:00:01  Dentro do prazo  10:00:00  10:59:59
# 25 0 days 00:00:01  Dentro do prazo  10:00:00  10:59:59
# 26 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 27 0 days 00:00:01  Dentro do prazo  10:00:00  10:59:59
# 28 0 days 00:00:01  Dentro do prazo  10:00:00  10:59:59
# 29 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 30 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 31 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 32 0 days 00:00:02  Dentro do prazo  10:00:00  10:59:59
# 33 0 days 00:00:04  Dentro do prazo  10:00:00  10:59:59
# 34 0 days 00:00:01  Dentro do prazo  10:00:00  10:59:59
# 35 0 days 00:00:03  Dentro do prazo  11:00:00  11:59:59
# 36 0 days 00:14:48  Dentro do prazo  11:00:00  11:59:59
# 37 0 days 00:03:54  Dentro do prazo  11:00:00  11:59:59
# 38 0 days 00:08:56  Dentro do prazo  11:00:00  11:59:59
# 39 0 days 00:05:19  Dentro do prazo  11:00:00  11:59:59
# 40 0 days 00:00:02  Dentro do prazo  11:00:00  11:59:59
# 41 0 days 00:00:02  Dentro do prazo  11:00:00  11:59:59
# 42 0 days 00:00:01  Dentro do prazo  11:00:00  11:59:59
# 43 0 days 00:00:04  Dentro do prazo  11:00:00  11:59:59
# 44 0 days 00:00:02  Dentro do prazo  11:00:00  11:59:59
# 45 0 days 00:00:02  Dentro do prazo  12:00:00  12:59:59
# 46 0 days 00:00:08  Dentro do prazo  12:00:00  12:59:59
# 47 0 days 00:00:05  Dentro do prazo  12:00:00  12:59:59
# 48 0 days 00:00:04  Dentro do prazo  12:00:00  12:59:59
# 49 0 days 00:00:02  Dentro do prazo  12:00:00  12:59:59

# %%
# Salvando as alterações em um novo dataset
dados.to_csv('Data Challengee.csv', index=False)

# %%
# Agrupando as senhas por hora
senhas_per_hour = dados.groupby(['ID_UOR','HH_INC']).count()['ID'].to_frame()
senhas_per_hour
# Out:
#                    ID
# ID_UOR HH_INC
# 0      09:00:00    17
#        10:00:00  4461
#        11:00:00  3650
#        12:00:00  3589
#        13:00:00  3553
# ...               ...
# 24     11:00:00  1007
#        12:00:00   626
#        13:00:00  1079
#        14:00:00   428
#        15:00:00    37
#
# [192 rows x 1 columns]

# %%
senhas_per_hour.to_csv()
# Out:
# 'ID_UOR,HH_INC,ID\n0,09:00:00,17\n0,10:00:00,4461\n0,11:00:00,3650\n0,12:00:00,3589\n0,13:00:00,3553\n0,14:00:00,2215\n0,15:00:00,224\n0,16:00:00,1\n1,08:00:00,8\n1,09:00:00,1877\n1,10:00:00,5956\n1,11:00:00,4951\n1,12:00:00,4354\n1,13:00:00,5498\n1,14:00:00,1626\n1,15:00:00,42\n2,08:00:00,1\n2,09:00:00,192\n2,10:00:00,3590\n2,11:00:00,2732\n2,12:00:00,2551\n2,13:00:00,3028\n2,14:00:00,1856\n2,15:00:00,207\n2,16:00:00,1\n4,08:00:00,1\n4,09:00:00,569\n4,10:00:00,4792\n4,11:00:00,3591\n4,12:00:00,3131\n4,13:00:00,3524\n4,14:00:00,1838\n4,15:00:00,206\n5,09:00:00,30\n5,10:00:00,1516\n5,11:00:00,4543\n5,12:00:00,3672\n5,13:00:00,3626\n5,14:00:00,2789\n5,15:00:00,2652\n5,16:00:00,457\n5,17:00:00,2\n6,09:00:00,16\n6,10:00:00,1800\n6,11:00:00,3663\n6,12:00:00,3236\n6,13:00:00,3124\n6,14:00:00,1939\n6,15:00:00,1774\n6,16:00:00,79\n7,09:00:00,1\n7,10:00:00,127\n7,11:00:00,159\n7,12:00:00,173\n7,13:00:00,137\n7,14:00:00,39\n7,15:00:00,1\n8,09:00:00,72\n8,10:00:00,2782\n8,11:00:00,11854\n8,12:00:00,9623\n8,13:00:00,9704\n8,14:00:00,7300\n8,15:00:00,7317\n8,16:00:00,108\n9,09:00:00,450\n9,10:00:00,4512\n9,11:00:00,2977\n9,12:00:00,2664\n9,13:00:00,3401\n9,14:00:00,1291\n9,15:00:00,51\n10,09:00:00,14\n10,10:00:00,816\n10,11:00:00,4209\n10,12:00:00,3820\n10,13:00:00,4247\n10,14:00:00,3292\n10,15:00:00,2959\n10,16:00:00,411\n10,17:00:00,14\n11,09:00:00,9\n11,10:00:00,552\n11,11:00:00,2019\n11,12:00:00,1562\n11,13:00:00,1427\n11,14:00:00,1297\n11,15:00:00,1159\n11,16:00:00,43\n12,09:00:00,30\n12,10:00:00,2519\n12,11:00:00,2206\n12,12:00:00,1562\n12,13:00:00,2139\n12,14:00:00,902\n12,15:00:00,27\n13,09:00:00,12\n13,10:00:00,57\n13,11:00:00,1402\n13,12:00:00,869\n13,13:00:00,1302\n13,14:00:00,1212\n13,15:00:00,1122\n13,16:00:00,139\n13,17:00:00,1\n14,09:00:00,3\n14,10:00:00,542\n14,11:00:00,1514\n14,12:00:00,1505\n14,13:00:00,1824\n14,14:00:00,1193\n14,15:00:00,918\n14,16:00:00,194\n14,17:00:00,13\n15,07:00:00,1\n15,08:00:00,1\n15,09:00:00,41\n15,10:00:00,1328\n15,11:00:00,3672\n15,12:00:00,3173\n15,13:00:00,3045\n15,14:00:00,1895\n15,15:00:00,1965\n15,16:00:00,398\n15,17:00:00,9\n16,09:00:00,6\n16,10:00:00,168\n16,11:00:00,635\n16,12:00:00,511\n16,13:00:00,308\n16,14:00:00,255\n16,15:00:00,249\n16,16:00:00,19\n17,11:00:00,4\n17,12:00:00,13\n17,13:00:00,7\n17,14:00:00,11\n17,15:00:00,4\n18,08:00:00,1\n18,09:00:00,58\n18,10:00:00,3027\n18,11:00:00,2311\n18,12:00:00,2186\n18,13:00:00,2594\n18,14:00:00,1091\n18,15:00:00,89\n18,16:00:00,1\n19,09:00:00,28\n19,10:00:00,1623\n19,11:00:00,5005\n19,12:00:00,4134\n19,13:00:00,4089\n19,14:00:00,3160\n19,15:00:00,2888\n19,16:00:00,101\n20,09:00:00,2\n20,10:00:00,69\n20,11:00:00,1430\n20,12:00:00,1133\n20,13:00:00,936\n20,14:00:00,944\n20,15:00:00,932\n20,16:00:00,77\n21,09:00:00,67\n21,10:00:00,4103\n21,11:00:00,3547\n21,12:00:00,2991\n21,13:00:00,3134\n21,14:00:00,1135\n21,15:00:00,57\n22,09:00:00,36\n22,10:00:00,5434\n22,11:00:00,4771\n22,12:00:00,4298\n22,13:00:00,4657\n22,14:00:00,1742\n22,15:00:00,127\n23,09:00:00,157\n23,10:00:00,3537\n23,11:00:00,3055\n23,12:00:00,2773\n23,13:00:00,2960\n23,14:00:00,1977\n23,15:00:00,137\n23,16:00:00,1\n24,09:00:00,13\n24,10:00:00,1365\n24,11:00:00,1007\n24,12:00:00,626\n24,13:00:00,1079\n24,14:00:00,428\n24,15:00:00,37\n'

# %%
# Separando os horários de retirada de senha e atendimento da data

# %%
dados['TS_INC_EPR'] = pd.to_datetime(dados['TS_INC_EPR'],format= '%H:%M:%S' ).dt.time
dados.head()
# Out:
#    ID  ID_UOR TS_INC_EPR         TS_INC_CHMD         DT      TS_TTL_EPR  \
# 0   0       0   10:01:24 2020-09-01 10:02:13 2020-09-01 0 days 00:00:49
# 1   1       0   10:04:21 2020-09-01 10:22:01 2020-09-01 0 days 00:17:40
# 2   2       0   10:16:14 2020-09-01 10:25:06 2020-09-01 0 days 00:08:52
# 3   3       0   10:28:38 2020-09-01 10:28:40 2020-09-01 0 days 00:00:02
# 4   4       0   10:37:38 2020-09-01 10:37:41 2020-09-01 0 days 00:00:03
#
#                ESP    HH_INC    HH_FIM
# 0  Dentro do prazo  10:00:00  20:59:59
# 1   Acima do prazo  10:00:00  20:59:59
# 2  Dentro do prazo  10:00:00  20:59:59
# 3  Dentro do prazo  10:00:00  20:59:59
# 4  Dentro do prazo  10:00:00  20:59:59

# %%
dados['TS_INC_CHMD'] = pd.to_datetime(dados['TS_INC_CHMD'],format= '%H:%M:%S' ).dt.time
dados.head()
# Out:
#    ID  ID_UOR TS_INC_EPR TS_INC_CHMD         DT      TS_TTL_EPR  \
# 0   0       0   10:01:24    10:02:13 2020-09-01 0 days 00:00:49
# 1   1       0   10:04:21    10:22:01 2020-09-01 0 days 00:17:40
# 2   2       0   10:16:14    10:25:06 2020-09-01 0 days 00:08:52
# 3   3       0   10:28:38    10:28:40 2020-09-01 0 days 00:00:02
# 4   4       0   10:37:38    10:37:41 2020-09-01 0 days 00:00:03
#
#                ESP    HH_INC    HH_FIM
# 0  Dentro do prazo  10:00:00  20:59:59
# 1   Acima do prazo  10:00:00  20:59:59
# 2  Dentro do prazo  10:00:00  20:59:59
# 3  Dentro do prazo  10:00:00  20:59:59
# 4  Dentro do prazo  10:00:00  20:59:59

# %%
# Imprimindo a frequência dos atendimentos realizados dentro do prazo e acima do prazo
freq = dados['ESP'].value_counts() 
print(freq)
# Out:
# Dentro do prazo    304987
# Acima do prazo      30441
# Name: ESP, dtype: int64

# %%
percentual = dados['ESP'].value_counts(normalize=True)

# %%
percentual
# Out:
# Dentro do prazo    0.909247
# Acima do prazo     0.090753
# Name: ESP, dtype: float64

# %%
dados.to_csv('./data/dados.csv',sep=',',index=False)
